# %%
import math

customers = ["Zoey Valentine", "Maddox Camacho", "Gillian Ponce", "Hannah Sawyer", "Naima Woodard", "Jonas Escobar",
 "Moses Diaz", "Grant Wells", "Leon Chan", "Mauricio Armstrong", "Rebecca Evans", "Andre Robinson"]

credit_scores = [497, 746, 723,  599, 754, 815, 843, 252, 288, 257, 632, 541]

purchases = [2051, 2846, 3547, 3027, 2254, 1440, 3032, 2107, 1752, 1434, 2434, 1343]

# ABC shoes has a list of customers stored in the customers list, the credit scores for those customers

# are stored in the credit_scores list and the customer purchases are stored in the purchases list

# The index in the list determines the correspondence between customers, scores, and purchases.

# For example for index 0, the customer is Zoey Valentine, their credit score is 497 and they purchased $2051

# in products

# ABC shoes is planning on launching a loyalty program to target their best customers.


# Complete the following code


# Using this chart https://www.nerdwallet.com/assets/blog/wp-content/uploads/2019/06/credit-score-ranges-600x450.png

# Count the number of customers that have a good or excellent credit score (will call this high score from now on). 

# Store the result in the high_score_count variable


high_score_count = 0

# Your code starts after this line

for credit_score in credit_scores:
    if credit_score >= 690:
        high_score_count = high_score_count + 1

# Your code ends before this line


print("High Score Count: " + str(high_score_count))

# Calculate the average product purchases across all customers store the result

# in the average_purchase variable.


average_purchase = 0

# Your code starts after this line



# Your code ends before this line


print("Average Purchase: " + str(round(average_purchase, 2)))

# Calculate the population standard deviation of the purchases

# Store the result in the variable std_purchase


std_purchase = 0

# Your code starts after this line


# Your code ends before this line


print("Purchase Standard Deviation: " + str(round(std_purchase, 2)))

# Assign loyalty status to customers based on this criteria (one customer can have only one status, 

# if they quality for more they get the highest one):

# Platinum = High Score and Purchases one standard deviation above the average

# Gold = High Score and Purchases above the average

# Silver = Hig Score or Purchases above average

# None = All other customers who don't qualify for one of the previous ones


# For each customer print their name, colon, space, and their status in the same order as the customers list

# For example: "John Doe: Platinum"


# Your code starts after this line



# Your code ends before this line
# Out:
# High Score Count: 5
# Average Purchase: 0
# Purchase Standard Deviation: 0

# %%
import math

customers = ["Zoey Valentine", "Maddox Camacho", "Gillian Ponce", "Hannah Sawyer", "Naima Woodard", "Jonas Escobar",
 "Moses Diaz", "Grant Wells", "Leon Chan", "Mauricio Armstrong", "Rebecca Evans", "Andre Robinson"]

credit_scores = [497, 746, 723,  599, 754, 815, 843, 252, 288, 257, 632, 541]

purchases = [2051, 2846, 3547, 3027, 2254, 1440, 3032, 2107, 1752, 1434, 2434, 1343]

# ABC shoes has a list of customers stored in the customers list, the credit scores for those customers

# are stored in the credit_scores list and the customer purchases are stored in the purchases list

# The index in the list determines the correspondence between customers, scores, and purchases.

# For example for index 0, the customer is Zoey Valentine, their credit score is 497 and they purchased $2051

# in products

# ABC shoes is planning on launching a loyalty program to target their best customers.


# Complete the following code


# Using this chart https://www.nerdwallet.com/assets/blog/wp-content/uploads/2019/06/credit-score-ranges-600x450.png

# Count the number of customers that have a good or excellent credit score (will call this high score from now on). 

# Store the result in the high_score_count variable


high_score_count = 0

# Your code starts after this line

for credit_score in credit_scores:
    if credit_score >= 690:
        high_score_count = high_score_count + 1

# Your code ends before this line


print("High Score Count: " + str(high_score_count))

# Calculate the average product purchases across all customers store the result

# in the average_purchase variable.


average_purchase = 0

# Your code starts after this line

sum = 0
count = 0

for purchase in purchases:
    sum = sum + purchase
    count = count + 1
    
average_purchase = sum / count


# Your code ends before this line


print("Average Purchase: " + str(round(average_purchase, 2)))

# Calculate the population standard deviation of the purchases

# Store the result in the variable std_purchase


std_purchase = 0

# Your code starts after this line

from math import sqrt

sum = 0
count = 0
for purchase in purchases:

    sum = sum + purchase
    count = count + 1

    mean = sum/count

sum = 0
count = 0
for purchase in purchases:

    sum += (purchase - mean) * (purchase - mean)
    count = count + 1

    std_purchase = sqrt(sum/count)

# Your code ends before this line

print("Purchase Standard Deviation: " + str(round(std_purchase, 2)))
# Out:
# High Score Count: 5
# Average Purchase: 2272.25
# Purchase Standard Deviation: 691.21

# %%
import math

customers = ["Zoey Valentine", "Maddox Camacho", "Gillian Ponce", "Hannah Sawyer", "Naima Woodard", "Jonas Escobar",
 "Moses Diaz", "Grant Wells", "Leon Chan", "Mauricio Armstrong", "Rebecca Evans", "Andre Robinson"]

credit_scores = [497, 746, 723,  599, 754, 815, 843, 252, 288, 257, 632, 541]

purchases = [2051, 2846, 3547, 3027, 2254, 1440, 3032, 2107, 1752, 1434, 2434, 1343]

# ABC shoes has a list of customers stored in the customers list, the credit scores for those customers

# are stored in the credit_scores list and the customer purchases are stored in the purchases list

# The index in the list determines the correspondence between customers, scores, and purchases.

# For example for index 0, the customer is Zoey Valentine, their credit score is 497 and they purchased $2051

# in products

# ABC shoes is planning on launching a loyalty program to target their best customers.


# Complete the following code


# Using this chart https://www.nerdwallet.com/assets/blog/wp-content/uploads/2019/06/credit-score-ranges-600x450.png

# Count the number of customers that have a good or excellent credit score (will call this high score from now on). 

# Store the result in the high_score_count variable


high_score_count = 0

# Your code starts after this line

for credit_score in credit_scores:
    if credit_score >= 690:
        high_score_count = high_score_count + 1

# Your code ends before this line


print("High Score Count: " + str(high_score_count))

# Calculate the average product purchases across all customers store the result

# in the average_purchase variable.


average_purchase = 0

# Your code starts after this line

sum = 0
count = 0

for purchase in purchases:
    sum = sum + purchase
    count = count + 1
    
average_purchase = sum / count


# Your code ends before this line


print("Average Purchase: " + str(round(average_purchase, 2)))

# Calculate the population standard deviation of the purchases

# Store the result in the variable std_purchase


std_purchase = 0

# Your code starts after this line

from math import sqrt

sum = 0
count = 0
for purchase in purchases:

    sum = sum + purchase
    count = count + 1

    mean = sum/count

sum = 0
count = 0
for purchase in purchases:

    sum += (purchase - mean) * (purchase - mean)
    count = count + 1

    std_purchase = sqrt(sum/count)

# Your code ends before this line

print("Purchase Standard Deviation: " + str(round(std_purchase, 2)))

# Assign loyalty status to customers based on this criteria (one customer can have only one status, 

# if they quality for more they get the highest one):

# Platinum = High Score and Purchases one standard deviation above the average

# Gold = High Score and Purchases above the average

# Silver = Hig Score or Purchases above average

# None = All other customers who don't qualify for one of the previous ones


# For each customer print their name, colon, space, and their status in the same order as the customers list

# For example: "John Doe: Platinum"

# Your code starts after this line

#calculating standard deviation for purchases

sum = 0
count = 0
for purchase in purchases:

    sum = sum + purchase
    count = count + 1

purchase_mean = sum/count

sum = 0
count = 0
for purchase in purchases:

    sum += (purchase - mean) * (purchase - purchase_mean)
    count = count + 1

std_purchase = sqrt(sum/count)
    
#calculating standard deviation for high scores

sum = 0
count = 0
for credit_score in credit_scores:

    sum = sum + credit_score
    count = count + 1

credit_mean = sum/count

sum = 0
count = 0
for credit_score in credit_scores:

    sum += (credit_score - credit_mean) * (credit_score - credit_mean)
    count = count + 1

std_credit = sqrt(sum/count)

high_score = 690

platinum_purchase = purchase_mean + std_purchase
 
for i in range(len(customers)):

    current_customer_name = customers[i]

    current_credit_score = credit_scores[i]

    current_purchase = purchases[i]

    if (current_credit_score >= high_score and current_purchase >= platinum_purchase):
        print(current_customer_name + ': Platinum')

    elif (current_credit_score >= high_score and current_purchase >= purchase_mean):
        print(current_customer_name + ': Gold')
        
    elif (current_credit_score >= high_score or current_purchase >= purchase_mean):
        print(current_customer_name + ': Silver')
    
    else:
        print(current_customer_name + ': None')

# Your code ends before this line
# Out:
# High Score Count: 5
# Average Purchase: 2272.25
# Purchase Standard Deviation: 691.21
# Zoey Valentine: None
# Maddox Camacho: Gold
# Gillian Ponce: Platinum
# Hannah Sawyer: Silver
# Naima Woodard: Silver
# Jonas Escobar: Silver
# Moses Diaz: Platinum
# Grant Wells: None
# Leon Chan: None
# Mauricio Armstrong: None
# Rebecca Evans: Silver
# Andre Robinson: None
